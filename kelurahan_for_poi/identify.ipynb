# %%
import pandas as pd

# %%
data = pd.read_csv('gis.dukcapil.kemendagri.xlsx - Batas Desa.csv')

# %%
print(len(data['nama_prop'].unique()))
# Out:
# 39

# %%
(data['nama_prop'].unique())
# Out:
# array(['JAWA TENGAH', 'ACEH', 'SULAWESI SELATAN', 'JAWA TIMUR',
#        'SUMATERA UTARA', 'PAPUA PEGUNUNGAN', 'RIAU', 'SUMATERA BARAT',
#        'SULAWESI TENGGARA', 'PAPUA', nan, 'JAWA BARAT', 'SULAWESI UTARA',
#        'SULAWESI TENGAH', 'LAMPUNG', 'BANTEN', 'NUSA TENGGARA TIMUR',
#        'PAPUA TENGAH', 'PAPUA BARAT DAYA', 'PAPUA BARAT',
#        'KALIMANTAN BARAT', 'GORONTALO', 'NUSA TENGGARA BARAT',
#        'PAPUA SELATAN', 'JAMBI', 'KALIMANTAN TIMUR', 'SUMATERA SELATAN',
#        'MALUKU', 'KALIMANTAN SELATAN', 'SULAWESI BARAT', 'BENGKULU',
#        'KALIMANTAN TENGAH', 'BALI', 'MALUKU UTARA', 'KALIMANTAN UTARA',
#        'DAERAH ISTIMEWA YOGYAKARTA', 'DKI JAKARTA', 'KEPULAUAN RIAU',
#        'KEPULAUAN BANGKA BELITUNG'], dtype=object)

# %%
data
# Out:
#        objectid  no_prop  no_kab  no_kec  no_kel  kode_desa_spatial  \
# 0       1335825     33.0     3.0     5.0  1012.0       3.303051e+09
# 1       1335826     11.0     1.0     1.0  2001.0       1.101012e+09
# 2       1335827     11.0     1.0     2.0  2009.0       1.101022e+09
# 3       1335828     73.0    12.0     6.0  2002.0       7.312062e+09
# 4       1335829     11.0     2.0     4.0  2011.0       1.102042e+09
# ...         ...      ...     ...     ...     ...                ...
# 83484   1419309     75.0     1.0    11.0  2025.0       7.501112e+09
# 83485   1419310     75.0     1.0    11.0  2013.0       7.501112e+09
# 83486   1419311     75.0     1.0     4.0  2003.0       7.501042e+09
# 83487   1419312     75.0     1.0     4.0  2001.0       7.501042e+09
# 83488   1419313     75.0     1.0     9.0  2018.0       7.501092e+09
#
#               nama_prop            nama_kab     nama_kec  \
# 0           JAWA TENGAH    KAB. PURBALINGGA  PURBALINGGA
# ...

# %%
df = data[data.notnull()]

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 83489 entries, 0 to 83488
# Columns: 104 entries, objectid to lainnya
# dtypes: float64(99), int64(1), object(4)
# memory usage: 66.2+ MB
# None

# %%
df['nama_prop'].unique()
# Out:
# array(['JAWA TENGAH', 'ACEH', 'SULAWESI SELATAN', 'JAWA TIMUR',
#        'SUMATERA UTARA', 'PAPUA PEGUNUNGAN', 'RIAU', 'SUMATERA BARAT',
#        'SULAWESI TENGGARA', 'PAPUA', nan, 'JAWA BARAT', 'SULAWESI UTARA',
#        'SULAWESI TENGAH', 'LAMPUNG', 'BANTEN', 'NUSA TENGGARA TIMUR',
#        'PAPUA TENGAH', 'PAPUA BARAT DAYA', 'PAPUA BARAT',
#        'KALIMANTAN BARAT', 'GORONTALO', 'NUSA TENGGARA BARAT',
#        'PAPUA SELATAN', 'JAMBI', 'KALIMANTAN TIMUR', 'SUMATERA SELATAN',
#        'MALUKU', 'KALIMANTAN SELATAN', 'SULAWESI BARAT', 'BENGKULU',
#        'KALIMANTAN TENGAH', 'BALI', 'MALUKU UTARA', 'KALIMANTAN UTARA',
#        'DAERAH ISTIMEWA YOGYAKARTA', 'DKI JAKARTA', 'KEPULAUAN RIAU',
#        'KEPULAUAN BANGKA BELITUNG'], dtype=object)

# %%
bandung_df = df[df['nama_kab']=="KOTA BANDUNG"]

# %%
bandung_df.to_csv('bandung.csv')

# %%
for index, row in bandung_df.iterrows():
    print(row.nama_kel ,row.nama_kec)
# Out:
# KARANG ANYAR ASTANA ANYAR
# CIBADAK ASTANA ANYAR
# PASTEUR SUKAJADI
# PASIRLUYU REGOL
# MARGASARI BUAHBATU
# GARUDA ANDIR
# PANJUNAN ASTANA ANYAR
# CIHAPIT BANDUNG WETAN
# ISOLA SUKASARI
# SUKALUYU CIBEUNYING KALER
# ANTAPANI KULON ANTAPANI
# CISARANTEN BINA HARAPAN ARCAMANIK
# BABAKAN BABAKAN CIPARAY
# SUKAPURA KIARACONDONG
# CISARANTEN KIDUL GEDEBAGE
# CIKAWAO LENGKONG
# KEBON PISANG SUMUR BANDUNG
# SUKAHAJI BABAKAN CIPARAY
# KARASAK ASTANA ANYAR
# MARGAHAYU UTARA BABAKAN CIPARAY
# KOPO BOJONGLOA KALER
# NYENGSERET ASTANA ANYAR
# JAMIKA BOJONGLOA KALER
# BABAKAN ASIH BOJONGLOA KALER
# MALEBER ANDIR
# KEBON JERUK ANDIR
# HUSEIN SASTRANEGARA CICENDO
# PASIRKALIKI CICENDO
# SUKARAJA CICENDO
# SUKAWARNA SUKAJADI
# SUKABUNGAH SUKAJADI
# LEDENG CIDADAP
# CIPAGANTI COBLONG
# KEBON WARU BATUNUNGGAL
# SARIJADI SUKASARI
# LEBAK SILIWANGI COBLONG
# CIATEUL REGOL
# BALONG GEDE REGOL
# GUMURUH BATUNUNGGAL
# PALEDANG LENGKONG
# CIJAGRA LENGKONG
# CIBUNTU BANDUNG KULON
# ...

# %%
bandung_df.head(10).to_csv('t.csv')

# %%
bandung_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 151 entries, 4696 to 79335
# Columns: 104 entries, objectid to lainnya
# dtypes: float64(99), int64(1), object(4)
# memory usage: 123.9+ KB

# %%
jakarta_df = df[df['nama_prop']=="DKI JAKARTA"]

# %%
jakarta_df
# Out:
#        objectid  no_prop  no_kab  no_kec  no_kel  kode_desa_spatial  \
# 4602    1340427     31.0    73.0     4.0  1006.0       3.173041e+09
# 6822    1342647     31.0    75.0     1.0  1001.0       3.175011e+09
# 6827    1342652     31.0    74.0     1.0  1006.0       3.174011e+09
# 6844    1342669     31.0    72.0     4.0  1007.0       3.172041e+09
# 6847    1342672     31.0    72.0     6.0  1001.0       3.172061e+09
# ...         ...      ...     ...     ...     ...                ...
# 82294   1418119     31.0    74.0     8.0  1003.0       3.174081e+09
# 82295   1418120     31.0    74.0     9.0  1002.0       3.174091e+09
# 82296   1418121     31.0    74.0    10.0  1001.0       3.174101e+09
# 82298   1418123     31.0    75.0     6.0  1001.0       3.175061e+09
# 82299   1418124     31.0    75.0     6.0  1007.0       3.175061e+09
#
#          nama_prop                   nama_kab       nama_kec  \
# 4602   DKI JAKARTA    KOTA ADM. JAKARTA BARAT        TAMBORA
# ...

# %%
jabar_df = df[df['nama_prop']=="JAWA BARAT"]

# %%
jabar_df
# Out:
#        objectid  no_prop  no_kab  no_kec  no_kel  kode_desa_spatial  \
# 122     1335947     32.0     5.0    20.0  2007.0       3.205202e+09
# 198     1336023     32.0     7.0     3.0  2003.0       3.207032e+09
# 207     1336032     32.0     7.0    10.0  2013.0       3.207102e+09
# 265     1336090     32.0     7.0    11.0  2013.0       3.207112e+09
# 415     1336240     32.0     7.0    12.0  2004.0       3.207122e+09
# ...         ...      ...     ...     ...     ...                ...
# 83287   1419112     32.0    14.0    14.0  2009.0       3.214142e+09
# 83288   1419113     32.0    14.0    16.0  2009.0       3.214162e+09
# 83289   1419114     32.0    16.0     8.0  2005.0       3.216082e+09
# 83290   1419115     32.0    16.0     8.0  2007.0       3.216082e+09
# 83291   1419116     32.0    16.0     1.0  2002.0       3.216012e+09
#
#         nama_prop         nama_kab        nama_kec       nama_kel  ...  \
# 122    JAWA BARAT       KAB. GARUT       CISURUPAN      BALEWANGI  ...
# ...

# %%
df['nama_prop'].unique()
# Out:
# array(['JAWA TENGAH', 'ACEH', 'SULAWESI SELATAN', 'JAWA TIMUR',
#        'SUMATERA UTARA', 'PAPUA PEGUNUNGAN', 'RIAU', 'SUMATERA BARAT',
#        'SULAWESI TENGGARA', 'PAPUA', nan, 'JAWA BARAT', 'SULAWESI UTARA',
#        'SULAWESI TENGAH', 'LAMPUNG', 'BANTEN', 'NUSA TENGGARA TIMUR',
#        'PAPUA TENGAH', 'PAPUA BARAT DAYA', 'PAPUA BARAT',
#        'KALIMANTAN BARAT', 'GORONTALO', 'NUSA TENGGARA BARAT',
#        'PAPUA SELATAN', 'JAMBI', 'KALIMANTAN TIMUR', 'SUMATERA SELATAN',
#        'MALUKU', 'KALIMANTAN SELATAN', 'SULAWESI BARAT', 'BENGKULU',
#        'KALIMANTAN TENGAH', 'BALI', 'MALUKU UTARA', 'KALIMANTAN UTARA',
#        'DAERAH ISTIMEWA YOGYAKARTA', 'DKI JAKARTA', 'KEPULAUAN RIAU',
#        'KEPULAUAN BANGKA BELITUNG'], dtype=object)
